# %%
# !pip install open3d sam2 ultralytics lap
# Out:
# Collecting open3d
#   Downloading open3d-0.19.0-cp310-cp310-manylinux_2_31_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: numpy>=1.18.0 in /home/netbot/.local/lib/python3.10/site-packages (from open3d) (1.26.4)
# Collecting dash>=2.6.0 (from open3d)
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Collecting werkzeug>=3.0.0 (from open3d)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting flask>=3.0.0 (from open3d)
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: nbformat>=5.7.0 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from open3d) (5.10.4)
# Collecting configargparse (from open3d)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: ipywidgets>=8.0.4 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from open3d) (8.1.5)
# Collecting addict (from open3d)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: pillow>=9.3.0 in /home/netbot/.local/lib/python3.10/site-packages (from open3d) (10.4.0)
# Requirement already satisfied: matplotlib>=3 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from open3d) (3.10.0)
# Collecting pandas>=1.0 (from open3d)
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Requirement already satisfied: pyyaml>=5.4.1 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from open3d) (6.0.2)
# Collecting scikit-learn>=0.21 (from open3d)
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: tqdm in /home/netbot/.local/lib/python3.10/site-packages (from open3d) (4.67.1)
# Collecting pyquaternion (from open3d)
#   Downloading pyquaternion-0.9.9-py3-none-any.whl.metadata (1.4 kB)
# Collecting flask>=3.0.0 (from open3d)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting werkzeug>=3.0.0 (from open3d)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /home/netbot/.local/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (5.24.1)
# Collecting dash-html-components==2.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash>=2.6.0->open3d)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata (from dash>=2.6.0->open3d)
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/netbot/.local/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (4.12.2)
# Requirement already satisfied: requests in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (2.32.3)
# Collecting retrying (from dash>=2.6.0->open3d)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (1.6.0)
# Requirement already satisfied: setuptools in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from dash>=2.6.0->open3d) (75.8.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from flask>=3.0.0->open3d) (3.1.5)
# Collecting itsdangerous>=2.1.2 (from flask>=3.0.0->open3d)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting click>=8.1.3 (from flask>=3.0.0->open3d)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting blinker>=1.6.2 (from flask>=3.0.0->open3d)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: comm>=0.1.3 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d) (8.32.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipywidgets>=8.0.4->open3d) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from matplotlib>=3->open3d) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from matplotlib>=3->open3d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from matplotlib>=3->open3d) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from matplotlib>=3->open3d) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from matplotlib>=3->open3d) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from matplotlib>=3->open3d) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from matplotlib>=3->open3d) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from nbformat>=5.7.0->open3d) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from nbformat>=5.7.0->open3d) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from nbformat>=5.7.0->open3d) (5.7.2)
# Collecting pytz>=2020.1 (from pandas>=1.0->open3d)
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.0->open3d)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: scipy>=1.6.0 in /home/netbot/.local/lib/python3.10/site-packages (from scikit-learn>=0.21->open3d) (1.14.1)
# Collecting joblib>=1.2.0 (from scikit-learn>=0.21->open3d)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.21->open3d)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from werkzeug>=3.0.0->open3d) (3.0.2)
# Requirement already satisfied: decorator in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (5.1.1)
# Requirement already satisfied: exceptiongroup in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/netbot/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.18.0)
# Requirement already satisfied: stack_data in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7.0->open3d) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/netbot/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.7.0->open3d) (4.3.6)
# Requirement already satisfied: tenacity>=6.2.0 in /home/netbot/.local/lib/python3.10/site-packages (from plotly>=5.0.0->dash>=2.6.0->open3d) (9.0.0)
# Requirement already satisfied: six>=1.5 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3->open3d) (1.17.0)
# Collecting zipp>=3.20 (from importlib-metadata->dash>=2.6.0->open3d)
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from requests->dash>=2.6.0->open3d) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from requests->dash>=2.6.0->open3d) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from requests->dash>=2.6.0->open3d) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from requests->dash>=2.6.0->open3d) (2025.1.31)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.7.0)
# Requirement already satisfied: wcwidth in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (3.0.0)
# Requirement already satisfied: pure-eval in /home/netbot/anaconda3/envs/sam2/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.0.4->open3d) (0.2.3)
# Downloading open3d-0.19.0-cp310-cp310-manylinux_2_31_x86_64.whl (447.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 27.6 MB/s eta 0:00:0000:0100:01
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 62.3 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 47.5 MB/s eta 0:00:0000:01
# Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 50.6 MB/s eta 0:00:00a 0:00:01
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Downloading pyquaternion-0.9.9-py3-none-any.whl (14 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Installing collected packages: pytz, dash-table, dash-html-components, dash-core-components, addict, zipp, werkzeug, tzdata, threadpoolctl, retrying, pyquaternion, joblib, itsdangerous, configargparse, click, blinker, scikit-learn, pandas, importlib-metadata, flask, dash, open3d
# Successfully installed addict-2.4.0 blinker-1.9.0 click-8.1.8 configargparse-1.7 dash-2.18.2 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 flask-3.0.3 importlib-metadata-8.6.1 itsdangerous-2.2.0 joblib-1.4.2 open3d-0.19.0 pandas-2.2.3 pyquaternion-0.9.9 pytz-2025.1 retrying-1.3.4 scikit-learn-1.6.1 threadpoolctl-3.5.0 tzdata-2025.1 werkzeug-3.0.6 zipp-3.21.0

# %%
import cv2
import numpy as np
import torch
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor
from ultralytics import YOLO
import os
import glob
import open3d as o3d

def segment_pointcloud(frame, points):
    # yolo setup
    model_path = 'yolo_model.pt'
    yolo_model = YOLO(model_path)

    # sam2 setup        
    checkpoint =  "sam2_hiera_small.pt"
    model_cfg = "sam2_hiera_s.yaml"
    predictor = SAM2ImagePredictor(build_sam2(model_cfg, checkpoint))
    # YOLO detection and SAM2 segmentation (using existing code)
    results = yolo_model.track(source=frame, persist=True, conf=0.6, verbose=False)
    if results[0].boxes.id is None:
        print("No object detected")
    else:
        masks_list = []
        bboxes = results[0].boxes.xyxy.cpu().numpy().astype(int)
        ids = results[0].boxes.id.cpu().numpy().astype(int)
        confidences = results[0].boxes.conf.cpu().numpy().astype(float)

        with torch.inference_mode(), torch.autocast("cuda", dtype=torch.bfloat16):
            predictor.set_image(frame)
            for box in bboxes:
                input_box = np.array(box).reshape(1, 4)            
                masks, _, _ = predictor.predict(box=input_box, multimask_output=False)
                mask = (masks > 0).astype(np.uint8) * 255
                masks_list.append(mask[0])

        # Visualize segmented image
        visualization_frame = frame.copy()
        for mask in masks_list:
            # Apply mask overlay on the image
            colored_mask = np.zeros_like(frame)
            colored_mask[mask > 0] = [0, 255, 0]  # Green overlay
            visualization_frame = cv2.addWeighted(visualization_frame, 1, colored_mask, 0.5, 0)
        
        # cv2.imshow("Segmented Image", visualization_frame)
        # cv2.waitKey(0)
        # cv2.destroyAllWindows()

        # Filter and visualize point cloud
        print(f"masks_list len: {len(masks_list)}")
        points_reshaped = points.reshape(480, 640, 3)
        #filtered_points = np.zeros_like(points_reshaped)
        for mask in masks_list:
            print("loop start")
            # Reshape points to match image dimensions (480, 640, 3)
            
            
            # Get points corresponding to the mask
            
            if 'filtered_points' not in locals():
                filtered_points = points_reshaped[mask > 0]
            else:
                filtered_points = np.vstack((filtered_points, points_reshaped[mask > 0]))
        return filtered_points
            
# Get all files from both directories
rgb_dir = "/home/netbot/Documents/Malak/Intel Realsense/strawberry_extracted_rgb"
pointcloud_dir = "/home/netbot/Documents/Malak/Intel Realsense/strawberry_extracted_pointcloud"
segmented_pcl_dir="/home/netbot/Documents/Malak/sam2/sam2/segmented_pointcloud"

rgb_files = sorted(glob.glob(os.path.join(rgb_dir, "*.png")))
pointcloud_files = sorted(glob.glob(os.path.join(pointcloud_dir, "*.txt")))

# Process each pair of files
for rgb_file, pc_file in zip(rgb_files, pointcloud_files):
    # Extract IDs to ensure they match
    rgb_id = os.path.basename(rgb_file).split('_')[-1].split('.')[0]
    pc_id = os.path.basename(pc_file).split('_')[-1].split('.')[0]
    
    if rgb_id == pc_id:
        # Load the files
        frame = cv2.imread(rgb_file)
        points = np.loadtxt(pc_file)
        
        # Process the files
        filtered_points = segment_pointcloud(frame, points)
        
        # Visualize results
        pcd = o3d.geometry.PointCloud()
        pcd.points = o3d.utility.Vector3dVector(filtered_points)
        o3d.visualization.draw_geometries([pcd])
        
        # Save the segmented point cloud
        output_file = os.path.join(segmented_pcl_dir, f"segmented_{pc_id}.ply")
        o3d.io.write_point_cloud(output_file, pcd)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW Error: Failed to detect any supported platform
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 3
# loop start
# loop start
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 2
# loop start
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 2
# loop start
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 2
# loop start
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# masks_list len: 1
# loop start
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.

# %%
# Visualize the segmented pointcloud

pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(filtered_points)
                
# Visualize filtered point cloud
o3d.visualization.draw_geometries([pcd])
# Out:
# [Open3D WARNING] GLFW initialized for headless rendering.
# [Open3D WARNING] GLFW Error: OSMesa: Library not found
# [Open3D WARNING] Failed to create window
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
